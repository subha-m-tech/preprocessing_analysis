# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset = dataset.drop(columns='sl_no')

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # Scenario 1 solution for this dataset

# %%
#here salary is NaN because the student is not placed so we can replace 0 with NaN.
#inplace =true means the data frame has to make changes permanent 
dataset["salary"].fillna(0, inplace=True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Scenario 2

# %%
dataset = pd.read_csv("Placement_Data_Full_Class.csv")
dataset = dataset.drop(columns='sl_no')

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#if you want to delete all the null rows use below lines
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 7        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
# # Scenario 3

# %%
dataset = pd.read_csv("Placement_Data_Full_Class.csv")
dataset = dataset.drop(columns='sl_no')

# %%
# if you want to replace the values with mean then use below lines
dataset["salary"].fillna(dataset["salary"].mean(), inplace=True)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status         salary
# ...

# %%
#quan, qual = Univariate.quanQual(dataset)
def quanQual(dataset):
        quan = []
        qual = []
        for column_name in dataset.columns:
            if dataset[column_name].dtype == 'O':
                qual.append(column_name)
            else:
                quan.append(column_name)
        return quan, qual

# %%
quan, qual = quanQual(dataset)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # how to handle missing values in one or more columns

# %%
dataset = pd.read_csv("Placement_Data_Full_Class.csv")
dataset = dataset.drop(columns='sl_no')

# %%
# how to handle missing values in one or more columns
import numpy as np
from sklearn.impute import SimpleImputer
im = SimpleImputer(missing_values=np.nan, strategy='mean')
im.fit(dataset[quan])
df = im.transform(dataset[quan])

# %%
df
# Out:
# array([[6.70000000e+01, 9.10000000e+01, 5.80000000e+01, 5.50000000e+01,
#         5.88000000e+01, 2.70000000e+05],
#        [7.93300000e+01, 7.83300000e+01, 7.74800000e+01, 8.65000000e+01,
#         6.62800000e+01, 2.00000000e+05],
#        [6.50000000e+01, 6.80000000e+01, 6.40000000e+01, 7.50000000e+01,
#         5.78000000e+01, 2.50000000e+05],
#        ...,
#        [6.70000000e+01, 6.70000000e+01, 7.30000000e+01, 5.90000000e+01,
#         6.97200000e+01, 2.95000000e+05],
#        [7.40000000e+01, 6.60000000e+01, 5.80000000e+01, 7.00000000e+01,
#         6.02300000e+01, 2.04000000e+05],
#        [6.20000000e+01, 5.80000000e+01, 5.30000000e+01, 8.90000000e+01,
#         6.02200000e+01, 2.88655405e+05]])

# %%
preprocessing_quan_table = pd.DataFrame(columns= quan, data=df)
preprocessing_quan_table
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p         salary
# 0    67.00  91.00     58.00     55.0  58.80  270000.000000
# 1    79.33  78.33     77.48     86.5  66.28  200000.000000
# 2    65.00  68.00     64.00     75.0  57.80  250000.000000
# 3    56.00  52.00     52.00     66.0  59.43  288655.405405
# 4    85.80  73.60     73.30     96.8  55.50  425000.000000
# ..     ...    ...       ...      ...    ...            ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.000000
# 211  58.00  60.00     72.00     74.0  53.62  275000.000000
# 212  67.00  67.00     73.00     59.0  69.72  295000.000000
# 213  74.00  66.00     58.00     70.0  60.23  204000.000000
# 214  62.00  58.00     53.00     89.0  60.22  288655.405405
#
# [215 rows x 6 columns]

# %%
cate_table = dataset[qual]

# %%
df = [preprocessing_quan_table, cate_table]

# %%
result = pd.concat(df, axis=1)

# %%
result
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.000000      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.000000      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.000000      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  288655.405405      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.000000      M  Central
# ..     ...    ...       ...      ...    ...            ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.000000      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.000000      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.000000      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.000000      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  288655.405405      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
result.to_csv("preprocessed_placement.csv")
